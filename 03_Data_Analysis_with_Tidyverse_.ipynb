# %% [markdown]
# ## Data Wrangling
# Data Wrangling is the process of gathering, collecting, and transforming Raw data into another format for better understanding, decision-making, accessing, and analysis in less time. Data Wrangling is also known as Data Munging.

# %%
# install packages
install.packages("gapminder")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
# Loading Packages
# Load the gapminder package
library(gapminder)
library(dplyr)
library(ggplot2)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
# view Data
head(gapminder)
# Out:
#   country     continent year lifeExp pop      gdpPercap
# 1 Afghanistan Asia      1952 28.801   8425333 779.4453
# 2 Afghanistan Asia      1957 30.332   9240934 820.8530
# 3 Afghanistan Asia      1962 31.997  10267083 853.1007
# 4 Afghanistan Asia      1967 34.020  11537966 836.1971
# 5 Afghanistan Asia      1972 36.088  13079460 739.9811
# 6 Afghanistan Asia      1977 38.438  14880372 786.1134

# %% [markdown]
# ### The `filter()` verb extracts particular observations based on a condition.

# %%
# Filter the gapminder dataset for the year 1957
gapminder %>% filter(year == 2002)
# Out:
#     country                  continent year lifeExp pop        gdpPercap
# 1   Afghanistan              Asia      2002 42.129    25268405   726.7341
# 2   Albania                  Europe    2002 75.651     3508512  4604.2117
# 3   Algeria                  Africa    2002 70.994    31287142  5288.0404
# 4   Angola                   Africa    2002 41.003    10866106  2773.2873
# 5   Argentina                Americas  2002 74.340    38331121  8797.6407
# 6   Australia                Oceania   2002 80.370    19546792 30687.7547
# 7   Austria                  Europe    2002 78.980     8148312 32417.6077
# 8   Bahrain                  Asia      2002 74.795      656397 23403.5593
# 9   Bangladesh               Asia      2002 62.013   135656790  1136.3904
# 10  Belgium                  Europe    2002 78.320    10311970 30485.8838
# 11  Benin                    Africa    2002 54.406     7026113  1372.8779
# 12  Bolivia                  Americas  2002 63.883     8445134  3413.2627
# ...

# %%
# Filtering for one country and one year
# Filter for China in 2002
gapminder %>% filter(year == 2002, country == 'China')
# Out:
#   country continent year lifeExp pop        gdpPercap
# 1 China   Asia      2002 72.028  1280400000 3119.281

# %%
gapminder %>% filter(pop >= pop/1000000, year == 2002,gdpPercap < 2000)
# Out:
#    country                  continent year lifeExp pop        gdpPercap
# 1  Afghanistan              Asia      2002 42.129    25268405  726.7341
# 2  Bangladesh               Asia      2002 62.013   135656790 1136.3904
# 3  Benin                    Africa    2002 54.406     7026113 1372.8779
# 4  Burkina Faso             Africa    2002 50.650    12251209 1037.6452
# 5  Burundi                  Africa    2002 47.360     7021078  446.4035
# 6  Cambodia                 Asia      2002 56.752    12926707  896.2260
# 7  Cameroon                 Africa    2002 49.856    15929988 1934.0114
# 8  Central African Republic Africa    2002 43.308     4048013  738.6906
# 9  Chad                     Africa    2002 50.525     8835739 1156.1819
# 10 Comoros                  Africa    2002 62.974      614382 1075.8116
# 11 Congo, Dem. Rep.         Africa    2002 44.966    55379852  241.1659
# 12 Cote d'Ivoire            Africa    2002 46.832    16252726 1648.8008
# ...

# %% [markdown]
# ### The `arrange()` to sort observations in ascending or descending order of a particular variable.

# %%
# Sort in ascending order of lifeExp
gapminder %>% arrange(lifeExp)
# Out:
#      country           continent year lifeExp pop       gdpPercap
# 1    Rwanda            Africa    1992 23.599   7290203   737.0686
# 2    Afghanistan       Asia      1952 28.801   8425333   779.4453
# 3    Gambia            Africa    1952 30.000    284320   485.2307
# 4    Angola            Africa    1952 30.015   4232095  3520.6103
# 5    Sierra Leone      Africa    1952 30.331   2143249   879.7877
# 6    Afghanistan       Asia      1957 30.332   9240934   820.8530
# 7    Cambodia          Asia      1977 31.220   6978607   524.9722
# 8    Mozambique        Africa    1952 31.286   6446316   468.5260
# 9    Sierra Leone      Africa    1957 31.570   2295678  1004.4844
# 10   Burkina Faso      Africa    1952 31.975   4469979   543.2552
# 11   Afghanistan       Asia      1962 31.997  10267083   853.1007
# 12   Angola            Africa    1957 31.999   4561361  3827.9405
# 13   Gambia            Africa    1957 32.065    323150   520.9267
# ...

# %%
# Sort in descending order of lifeExp
gapminder %>% arrange(desc(lifeExp))
# Out:
#      country           continent year lifeExp pop       gdpPercap
# 1    Japan             Asia      2007 82.603  127467972 31656.07
# 2    Hong Kong, China  Asia      2007 82.208    6980412 39724.98
# 3    Japan             Asia      2002 82.000  127065841 28604.59
# 4    Iceland           Europe    2007 81.757     301931 36180.79
# 5    Switzerland       Europe    2007 81.701    7554661 37506.42
# 6    Hong Kong, China  Asia      2002 81.495    6762476 30209.02
# 7    Australia         Oceania   2007 81.235   20434176 34435.37
# 8    Spain             Europe    2007 80.941   40448191 28821.06
# 9    Sweden            Europe    2007 80.884    9031088 33859.75
# 10   Israel            Asia      2007 80.745    6426679 25523.28
# 11   Japan             Asia      1997 80.690  125956499 28816.58
# 12   France            Europe    2007 80.657   61083916 30470.02
# 13   Canada            Americas  2007 80.653   33390141 36319.24
# ...

# %%
# Filtering and arranging
# Filter for the year 1957, then arrange in descending order of population
gapminder %>% 
          filter(year == 1957) %>% 
          arrange(desc(pop))
# Out:
#     country               continent year lifeExp  pop       gdpPercap
# 1   China                 Asia      1957 50.54896 637408000   575.9870
# 2   India                 Asia      1957 40.24900 409000000   590.0620
# 3   United States         Americas  1957 69.49000 171984000 14847.1271
# 4   Japan                 Asia      1957 65.50000  91563009  4317.6944
# 5   Indonesia             Asia      1957 39.91800  90124000   858.9003
# 6   Germany               Europe    1957 69.10000  71019069 10187.8267
# 7   Brazil                Americas  1957 53.28500  65551171  2487.3660
# 8   United Kingdom        Europe    1957 70.42000  51430000 11283.1779
# 9   Bangladesh            Asia      1957 39.34800  51365468   661.6375
# 10  Italy                 Europe    1957 67.81000  49182000  6248.6562
# 11  Pakistan              Asia      1957 45.55700  46679944   747.0835
# 12  France                Europe    1957 68.93000  44310863  8662.8349
# ...

# %% [markdown]
# ### The `mutate()` verb to change this column, or to create a new column.

# %%
# Use mutate to create a new column called lifeExpMonths
gapminder %>% mutate(lifeExpMonths = 12 * lifeExp)
# Out:
#      country     continent year lifeExp pop      gdpPercap lifeExpMonths
# 1    Afghanistan Asia      1952 28.801   8425333  779.4453 345.612
# 2    Afghanistan Asia      1957 30.332   9240934  820.8530 363.984
# 3    Afghanistan Asia      1962 31.997  10267083  853.1007 383.964
# 4    Afghanistan Asia      1967 34.020  11537966  836.1971 408.240
# 5    Afghanistan Asia      1972 36.088  13079460  739.9811 433.056
# 6    Afghanistan Asia      1977 38.438  14880372  786.1134 461.256
# 7    Afghanistan Asia      1982 39.854  12881816  978.0114 478.248
# 8    Afghanistan Asia      1987 40.822  13867957  852.3959 489.864
# 9    Afghanistan Asia      1992 41.674  16317921  649.3414 500.088
# 10   Afghanistan Asia      1997 41.763  22227415  635.3414 501.156
# 11   Afghanistan Asia      2002 42.129  25268405  726.7341 505.548
# 12   Afghanistan Asia      2007 43.828  31889923  974.5803 525.936
# 13   Albania     Europe    1952 55.230   1282697 1601.0561 662.760
# ...

# %%
# Population in million
gapminder %>% mutate(pop	 = pop / 1000000)
# Out:
#      country     continent year lifeExp pop       gdpPercap
# 1    Afghanistan Asia      1952 28.801   8.425333  779.4453
# 2    Afghanistan Asia      1957 30.332   9.240934  820.8530
# 3    Afghanistan Asia      1962 31.997  10.267083  853.1007
# 4    Afghanistan Asia      1967 34.020  11.537966  836.1971
# 5    Afghanistan Asia      1972 36.088  13.079460  739.9811
# 6    Afghanistan Asia      1977 38.438  14.880372  786.1134
# 7    Afghanistan Asia      1982 39.854  12.881816  978.0114
# 8    Afghanistan Asia      1987 40.822  13.867957  852.3959
# 9    Afghanistan Asia      1992 41.674  16.317921  649.3414
# 10   Afghanistan Asia      1997 41.763  22.227415  635.3414
# 11   Afghanistan Asia      2002 42.129  25.268405  726.7341
# 12   Afghanistan Asia      2007 43.828  31.889923  974.5803
# 13   Albania     Europe    1952 55.230   1.282697 1601.0561
# 14   Albania     Europe    1957 59.280   1.476505 1942.2842
# 15   Albania     Europe    1962 64.820   1.728137 2312.8890
# ...

# %%
# Filter, mutate, and arrange the gapminder dataset
gapminder %>% filter(year == 2007) %>% 
mutate(pop_million	 = pop / 1000000) %>% arrange(desc(pop_million))
# Out:
#     country               continent year lifeExp pop        gdpPercap
# 1   China                 Asia      2007 72.961  1318683096  4959.1149
# 2   India                 Asia      2007 64.698  1110396331  2452.2104
# 3   United States         Americas  2007 78.242   301139947 42951.6531
# 4   Indonesia             Asia      2007 70.650   223547000  3540.6516
# 5   Brazil                Americas  2007 72.390   190010647  9065.8008
# 6   Pakistan              Asia      2007 65.483   169270617  2605.9476
# 7   Bangladesh            Asia      2007 64.062   150448339  1391.2538
# 8   Nigeria               Africa    2007 46.859   135031164  2013.9773
# 9   Japan                 Asia      2007 82.603   127467972 31656.0681
# 10  Mexico                Americas  2007 76.195   108700891 11977.5750
# 11  Philippines           Asia      2007 71.688    91077287  3190.4810
# 12  Vietnam               Asia      2007 74.249    85262356  2441.5764
# ...

# %% [markdown]
# ## Data Visualization

# %%
# creating new df for year 2007
gapminder <- gapminder %>% mutate(gdp = pop * gdpPercap)
gapminder_2007 <- gapminder %>% filter(year == 2007)
head(gapminder_2007)
# Out:
#   country     continent year lifeExp pop      gdpPercap  gdp
# 1 Afghanistan Asia      2007 43.828  31889923   974.5803  31079291949
# 2 Albania     Europe    2007 76.423   3600523  5937.0295  21376411360
# 3 Algeria     Africa    2007 72.301  33333216  6223.3675 207444851958
# 4 Angola      Africa    2007 42.731  12420476  4797.2313  59583895818
# 5 Argentina   Americas  2007 75.320  40301927 12779.3796 515033625357
# 6 Australia   Oceania   2007 81.235  20434176 34435.3674 703658358894

# %%
ggplot(gapminder_2007, aes(x=lifeExp,y= gdpPercap,color = continent,size = gdp)) + 
geom_point()
# Out:
# plot without title

# %%
gapminder <- gapminder %>% mutate(gdp = pop * gdpPercap)
head(gapminder)
# Out:
#   country     continent year lifeExp pop      gdpPercap gdp         color
# 1 Afghanistan Asia      1952 28.801   8425333 779.4453   6567086330 Asia
# 2 Afghanistan Asia      1957 30.332   9240934 820.8530   7585448670 Asia
# 3 Afghanistan Asia      1962 31.997  10267083 853.1007   8758855797 Asia
# 4 Afghanistan Asia      1967 34.020  11537966 836.1971   9648014150 Asia
# 5 Afghanistan Asia      1972 36.088  13079460 739.9811   9678553274 Asia
# 6 Afghanistan Asia      1977 38.438  14880372 786.1134  11697659231 Asia

# %%
ggplot(gapminder_2007, aes(x=lifeExp,y= gdp,,color = continent,size= pop)) + 
geom_point()
# Out:
# plot without title

# %%
gapminder_2007 <- gapminder_2007 %>% mutate(log_gdp = log10(gdp))
head(gapminder_2007)
# Out:
#   country     continent year lifeExp pop      gdpPercap  gdp          log_gdp
# 1 Afghanistan Asia      2007 43.828  31889923   974.5803  31079291949 10.49247
# 2 Albania     Europe    2007 76.423   3600523  5937.0295  21376411360 10.32993
# 3 Algeria     Africa    2007 72.301  33333216  6223.3675 207444851958 11.31690
# 4 Angola      Africa    2007 42.731  12420476  4797.2313  59583895818 10.77513
# 5 Argentina   Americas  2007 75.320  40301927 12779.3796 515033625357 11.71184
# 6 Australia   Oceania   2007 81.235  20434176 34435.3674 703658358894 11.84736

# %%
ggplot(gapminder, aes(x=lifeExp,y= gdpPercap,color=year)) + 
geom_point() +
scale_y_log10() +
facet_wrap(~continent)
# Out:
# plot without title

# %%
ggplot(gapminder, aes(x=lifeExp,y= gdpPercap,color=continent)) + 
geom_point() +
scale_y_log10() +
facet_wrap(~year)
# Out:
# plot without title

# %%
china = gapminder %>% filter(country == "China")
head(china)
# Out:
#   country continent year lifeExp  pop       gdpPercap gdp          color
# 1 China   Asia      1952 44.00000 556263527 400.4486  222754956737 Asia
# 2 China   Asia      1957 50.54896 637408000 575.9870  367138722270 Asia
# 3 China   Asia      1962 44.50136 665770000 487.6740  324678731164 Asia
# 4 China   Asia      1967 58.38112 754550000 612.7057  462317080955 Asia
# 5 China   Asia      1972 63.11888 862030000 676.9001  583508186393 Asia
# 6 China   Asia      1977 63.96736 943455000 741.2375  699324197165 Asia

# %%
high <- gapminder %>% filter(pop >100000000	)

ggplot(high,aes(x=year,y=pop,color=country)) +
geom_point() +
scale_y_log10() +
geom_line()
# Out:
# plot without title
